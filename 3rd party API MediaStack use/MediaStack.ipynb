# %%
import http.client, urllib.parse
import requests
import json
conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': '325490ab1e265963d046fa76ec53fe98',
    'categories': '-general,-sports',
    'sort': 'published_desc',
    'limit': 10,
    "country": "us",
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()
news= data.decode('utf-8')

# %%
absData  = json.loads(data)

# %%
allData=absData['data']
allData
# Out:
# [{'author': None,
#   'category': 'technology',
#   'country': 'au',
#   'description': "Audi's Luxury Q7 SUV still a firm favourite&nbsp;&nbsp;2GB",
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T23:07:14+00:00',
#   'source': 'Google News Technology AU',
#   'title': "Audi's Luxury Q7 SUV still a firm favourite - 2GB",
#   'url': 'https://news.google.com/__i/rss/rd/articles/CBMiR2h0dHBzOi8vd3d3LjJnYi5jb20vcG9kY2FzdC9hdWRpcy1sdXh1cnktcTctc3V2LXN0aWxsLWEtZmlybS1mYXZvdXJpdGUv0gEA?oc=5'},
#  {'author': 'Luke Broadwater',
#   'category': 'politics',
#   'country': 'us',
#   'description': 'A group of senators and senators-elect, led by Ted Cruz of Texas, said that they would object to the outcome of the election, while conceding that their effort would be unsuccessful.',
#   'image': 'https://static01.nyt.com/images/2021/01/02/us/politics/02dc-cong2/02dc-cong2-moth.jpg',
#   'language': 'en',
#   'published_at': '2021-01-02T23:05:24+00:00',
#   'source': 'The New York Times',
#   'title': '11 More Republican Senators Plan to Back Futile Bid to Overturn Biden’s Election',
#   'url': 'https://www.nytimes.com/2021/01/02/us/politics/gop-senators-josh-hawley-election.html'},
#  {'author': None,
#   'category': 'entertainment',
#   'country': 'au',
#   'description': "On January 4, 1971, Sesame Street debuted on Australian television. The landmark series, originally produced by the Children's Television Workshop and featuring the muppets created by the genius of Jim Henson, has enchanted and educated Australian children for 50 years.",
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T23:00:00+00:00',
#   'source': 'The Age',
#   'title': 'From the Archives: Sesame Street, enchanting Australian children for 50 years',
#   'url': 'https://www.theage.com.au/culture/tv-and-radio/from-the-archives-sesame-street-enchanting-australian-children-for-50-years-20201223-p56ptf.html?ref=rss&utm_medium=rss&utm_source=rss_culture'},
#  {'author': None,
#   'category': 'entertainment',
#   'country': 'au',
#   'description': "On January 4, 1971, Sesame Street debuted on Australian television. The landmark series, originally produced by the Children's Television Workshop and featuring the muppets created by the genius of Jim Henson, has enchanted and educated Australian children for 50 years.",
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T23:00:00+00:00',
#   'source': 'The Age',
#   'title': 'From the Archives: Sesame Street, enchanting Australian children for 50 years',
#   'url': 'https://www.theage.com.au/culture/tv-and-radio/from-the-archives-sesame-street-enchanting-australian-children-for-50-years-20201223-p56ptf.html?ref=rss&utm_medium=rss&utm_source=rss_culture'},
#  {'author': None,
#   'category': 'technology',
#   'country': 'au',
#   'description': '[Update: Jan. 02] Samsung Android 11 (One UI 3.0) update tracker: Galaxy devices that have received the beta/stable OS so far&nbsp;&nbsp;PiunikaWebSamsung Galaxy S21 Ultra Specifications, Release Date, Latest News&nbsp;&nbsp;NDTV[Update: Jan. 01] Samsung Android 11 (One UI 3.0) update tracker: Galaxy devices that have received the beta/stable OS so far&nbsp;&nbsp;PiunikaWebSamsung Galaxy S21+ Specifications, Release Date, Latest News&nbsp;&nbsp;NDTVView Full coverage on Google News',
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T22:58:07+00:00',
#   'source': 'Google News Technology AU',
#   'title': '[Update: Jan. 02] Samsung Android 11 (One UI 3.0) update tracker: Galaxy devices that have received the beta/stable OS so far - PiunikaWeb',
#   'url': 'https://news.google.com/__i/rss/rd/articles/CBMiT2h0dHBzOi8vcGl1bmlrYXdlYi5jb20vMjAyMS8wMS8wMi9zYW1zdW5nLWFuZHJvaWQtMTEtb25lLXVpLTMtMC11cGRhdGUtdHJhY2tlci_SAQA?oc=5'},
#  {'author': None,
#   'category': 'entertainment',
#   'country': 'nl',
#   'description': 'Hoewel Mark Rutte een dringend beroep op alle Nederlanders heeft gedaan om de komende tijd niet op vakantie te gaan vanwege de coronapandemie, heeft Estelle Cruijff vlak voor de jaarwisseling het vliegtuig gepakt om vakantie te vieren in Dubai.',
#   'image': None,
#   'language': 'nl',
#   'published_at': '2021-01-02T22:52:46+00:00',
#   'source': 'De Telegraaf - Entertainment Gossip',
#   'title': 'Estelle Cruijff met Lil’Kleine in Dubai',
#   'url': 'https://www.telegraaf.nl/entertainment/1757402661/estelle-cruijff-met-lil-kleine-in-dubai'},
#  {'author': 'Reuters',
#   'category': 'business',
#   'country': 'us',
#   'description': "U.S. Senator Cruz leads long-shot Republican bid to overturn Biden's victory",
#   'image': 'https://i-invdn-com.akamaized.net/trkd-images/LYNXMPEH0108G_L.jpg',
#   'language': 'en',
#   'published_at': '2021-01-02T22:51:10+00:00',
#   'source': 'Investing.com | Stock Market Quotes &amp; Financial News',
#   'title': "U.S. Senator Cruz leads long-shot Republican bid to overturn Biden's victory",
#   'url': 'https://www.investing.com/news/politics/us-senator-cruz-joins-republican-block-that-will-object-to-bidens-victory-2378559'},
#  {'author': 'Reuters',
#   'category': 'business',
#   'country': 'us',
#   'description': 'NBA-Paul Westphal, Hall of Fame player turned coach, dies at 70',
#   'image': 'https://i-invdn-com.akamaized.net/trkd-images/LYNXMPEH010AY_L.jpg',
#   'language': 'en',
#   'published_at': '2021-01-02T22:50:28+00:00',
#   'source': 'Investing.com | Stock Market Quotes &amp; Financial News',
#   'title': 'NBA-Paul Westphal, Hall of Fame player turned coach, dies at 70',
#   'url': 'https://www.investing.com/news/general/nbapaul-westphal-hall-of-fame-player-turned-coach-dies-at-70-2378603'},
#  {'author': 'TMZ Staff',
#   'category': 'entertainment',
#   'country': 'us',
#   'description': 'Ron Dominguez -- one of Disney\'s homegrown executives, quite literally -- has died. Dominguez, also known as "Mr. Disneyland," passed away Friday ... this according to the Disneyland Alumni Club. A cause of death wasn\'t revealed, but the guy\'s rich&hellip;',
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T22:40:16+00:00',
#   'source': 'TMZ',
#   'title': "'Mr. Disneyland' Ron Dominguez Dead at 85",
#   'url': 'https://www.tmz.com/2021/01/02/mr-disneyland-ron-dominguez-dead-dies-disney-legend/'},
#  {'author': 'Far Eastern Federal University',
#   'category': 'science',
#   'country': 'us',
#   'description': 'Scientists from Russia and Switzerland have probed into nanostructures covering the corneas of the eyes of small fruit flies. Investigating them the team learned how...\nThe post Scientists Replicate Self-Cleaning Anti-reflective Nanocoating of Insects’ Eyes appeared first on SciTechDaily.',
#   'image': None,
#   'language': 'en',
#   'published_at': '2021-01-02T22:33:11+00:00',
#   'source': 'Scitechdaily | Science Space And Technology News 2017',
#   'title': 'Scientists Replicate Self-Cleaning Anti-reflective Nanocoating of Insects’ Eyes',
#   'url': 'https://scitechdaily.com/scientists-replicate-self-cleaning-anti-reflective-nanocoating-of-insects-eyes/'}]

# %%
for i in allData:
  print(i['author'])
# Out:
# None
# Luke Broadwater
# None
# None
# None
# None
# Reuters
# Reuters
# TMZ Staff
# Far Eastern Federal University
